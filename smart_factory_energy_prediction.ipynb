# %%
import pandas as pd
import numpy as np

# %%
# Load the data
df = pd.read_csv('data/data.csv')

# %%
# Preview the first few rows
df.head(5)
# Out:
#              timestamp equipment_energy_consumption     lighting_energy  \
# 0  2016-01-11 17:00:00                         60.0  -77.78778596503064
# 1  2016-01-11 17:10:00                         60.0                30.0
# 2  2016-01-11 17:20:00                         50.0                30.0
# 3  2016-01-11 17:30:00                         50.0                40.0
# 4  2016-01-11 17:40:00                         60.0                40.0
#
#    zone1_temperature     zone1_humidity zone2_temperature  zone2_humidity  \
# 0  33.74660933896648  47.59666666666671              19.2       44.790000
# 1              19.89  46.69333333333329              19.2       44.722500
# 2              19.89               46.3              19.2       44.626667
# 3  33.74660933896648   46.0666666666667              19.2       44.590000
# 4              19.89  46.33333333333329              19.2       44.530000
#
#    zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# 0              19.79             NaN          19.000000  ...
# 1              19.79       44.790000          19.000000  ...
# 2              19.79       44.933333          35.921144  ...
# 3              19.79       45.000000                NaN  ...
# 4              19.79       45.000000          18.890000  ...
#
#    zone9_temperature  zone9_humidity  outdoor_temperature  \
# 0          17.033333           45.53             6.600000
# 1          17.066667           45.56             6.483333
# 2          17.000000           45.50             6.366667
# 3          17.000000           45.40             6.250000
# 4           4.476511           45.40             6.133333
#
#    atmospheric_pressure  outdoor_humidity  wind_speed  visibility_index  \
# 0                 733.5              92.0    7.000000         63.000000
# 1                 733.6              92.0    6.666667         59.166667
# 2                 733.7              92.0    6.333333         55.333333
# 3                 733.8              92.0    6.000000         51.500000
# 4                 733.9              92.0    5.666667         47.666667
#
#    dew_point  random_variable1  random_variable2
# 0   5.300000         13.275433         13.275433
# 1   5.200000         18.606195         18.606195
# 2   5.100000         28.642668         28.642668
# 3  37.673716         45.410389         45.410389
# 4   4.900000         10.084097         10.084097
#
# [5 rows x 29 columns]

# %%
# Display dimensions
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (16857, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     16857 non-null  object
#  1   equipment_energy_consumption  16013 non-null  object
#  2   lighting_energy               16048 non-null  object
#  3   zone1_temperature             15990 non-null  object
#  4   zone1_humidity                16056 non-null  object
#  5   zone2_temperature             16004 non-null  object
#  6   zone2_humidity                15990 non-null  float64
#  7   zone3_temperature             16055 non-null  float64
#  8   zone3_humidity                15979 non-null  float64
#  9   zone4_temperature             16041 non-null  float64
#  10  zone4_humidity                16076 non-null  float64
#  11  zone5_temperature             16019 non-null  float64
#  12  zone5_humidity                16056 non-null  float64
#  13  zone6_temperature             16009 non-null  float64
#  14  zone6_humidity                16010 non-null  float64
#  15  zone7_temperature             16063 non-null  float64
#  16  zone7_humidity                16052 non-null  float64
#  17  zone8_temperature             16009 non-null  float64
#  18  zone8_humidity                16080 non-null  float64
#  19  zone9_temperature             16084 non-null  float64
#  20  zone9_humidity                15969 non-null  float64
#  21  outdoor_temperature           16051 non-null  float64
#  22  atmospheric_pressure          16015 non-null  float64
#  23  outdoor_humidity              16058 non-null  float64
#  24  wind_speed                    16029 non-null  float64
#  25  visibility_index              16042 non-null  float64
#  26  dew_point                     16031 non-null  float64
#  27  random_variable1              16031 non-null  float64
#  28  random_variable2              16033 non-null  float64
# dtypes: float64(23), object(6)
# memory usage: 3.7+ MB

# %%
df.describe().T
# Out:
#                         count        mean        std         min         25%  \
# zone2_humidity        15990.0   39.494553  10.129513  -77.265503   37.757500
# zone3_temperature     16055.0   21.665733   2.594309    6.543921   20.533333
# zone3_humidity        15979.0   38.201314  10.144388  -71.406273   36.592500
# zone4_temperature     16041.0   20.239922   2.783050    4.613485   19.266667
# zone4_humidity        16076.0   37.945608  10.769813  -81.446225   35.200000
# zone5_temperature     16019.0   19.052613   2.346158    5.921094   18.061111
# zone5_humidity        16056.0   50.289131  18.722516 -141.640143   45.290000
# zone6_temperature     16009.0    6.469934   8.867993  -42.987365    2.930000
# zone6_humidity        16010.0   59.162913  52.657787 -353.393026   37.066667
# zone7_temperature     16063.0   19.672472   2.879815    3.578021   18.500000
# zone7_humidity        16052.0   34.032621  11.345440  -84.882898   31.000000
# zone8_temperature     16009.0   21.606344   2.974989    4.502372   20.500000
# zone8_humidity        16080.0   41.853532  12.301530  -94.385668   38.626667
# zone9_temperature     16084.0   18.851085   2.528783    4.476511   17.890000
# zone9_humidity        15969.0   40.318199  11.168678  -81.582494   38.230000
# outdoor_temperature   16051.0    6.218582   7.554684  -37.524768    3.000000
# atmospheric_pressure  16015.0  755.757602  13.643585  678.159940  750.800000
# outdoor_humidity      16058.0   78.977595  28.565660 -221.668765   71.000000
# wind_speed            16029.0    4.195988   4.409729  -20.929527    2.000000
# visibility_index      16042.0   38.457150  21.318655  -82.329792   29.000000
# dew_point             16031.0    2.783507   6.094732  -32.098095    0.450000
# random_variable1      16031.0   24.854981  26.214960 -120.170177   12.179924
# random_variable2      16033.0   25.093780  25.523631 -120.409590   12.193789
#
#                              50%         75%         max
# zone2_humidity         40.293333   43.000000   77.265503
# zone3_temperature      21.767500   22.760000   36.823982
# zone3_humidity         38.400000   41.433333   71.406273
# zone4_temperature      20.290000   21.356667   35.921144
# zone4_humidity         38.090000   41.560833   81.446225
# zone5_temperature      19.050000   20.100000   32.157594
# zone5_humidity         48.854429   53.918333  141.640143
# zone6_temperature       6.263333    9.690000   55.932271
# zone6_humidity         62.766667   86.590000  353.393026
# zone7_temperature      19.600000   21.000000   35.712952
# zone7_humidity         34.230000   38.156667   84.882898
# zone8_temperature      21.790000   22.790000   38.626835
# zone8_humidity         42.040455   46.003889   94.385668
# zone9_temperature      18.890000   20.200000   33.238012
# zone9_humidity         40.363333   43.790000   81.582494
# outdoor_temperature     6.000000    9.250000   49.853906
# atmospheric_pressure  756.200000  762.100000  833.392675
# outdoor_humidity       84.166667   91.988095  221.668765
# wind_speed              4.000000    6.000000   29.318719
# visibility_index       40.000000   40.000000  159.606156
# dew_point               2.750000    5.308333   37.673716
# random_variable1       24.866978   37.950236  170.156325
# random_variable2       24.834261   37.971764  170.329617

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
for col in df.columns:
    if df[col].dtype == 'object' and col != 'timestamp':
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     16857 non-null  datetime64[ns]
#  1   equipment_energy_consumption  15945 non-null  float64
#  2   lighting_energy               15993 non-null  float64
#  3   zone1_temperature             15908 non-null  float64
#  4   zone1_humidity                15969 non-null  float64
#  5   zone2_temperature             15934 non-null  float64
#  6   zone2_humidity                15990 non-null  float64
#  7   zone3_temperature             16055 non-null  float64
#  8   zone3_humidity                15979 non-null  float64
#  9   zone4_temperature             16041 non-null  float64
#  10  zone4_humidity                16076 non-null  float64
#  11  zone5_temperature             16019 non-null  float64
#  12  zone5_humidity                16056 non-null  float64
#  13  zone6_temperature             16009 non-null  float64
#  14  zone6_humidity                16010 non-null  float64
#  15  zone7_temperature             16063 non-null  float64
#  16  zone7_humidity                16052 non-null  float64
#  17  zone8_temperature             16009 non-null  float64
#  18  zone8_humidity                16080 non-null  float64
#  19  zone9_temperature             16084 non-null  float64
#  20  zone9_humidity                15969 non-null  float64
#  21  outdoor_temperature           16051 non-null  float64
#  22  atmospheric_pressure          16015 non-null  float64
#  23  outdoor_humidity              16058 non-null  float64
#  24  wind_speed                    16029 non-null  float64
#  25  visibility_index              16042 non-null  float64
#  26  dew_point                     16031 non-null  float64
#  27  random_variable1              16031 non-null  float64
#  28  random_variable2              16033 non-null  float64
# dtypes: datetime64[ns](1), float64(28)
# memory usage: 3.7 MB

# %%
# Check for duplicates
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 68

# %%
# Check target column
df['equipment_energy_consumption'].describe()
# Out:
# count    15945.000000
# mean        95.810413
# std        182.753554
# min      -1139.985693
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1139.985693
# Name: equipment_energy_consumption, dtype: float64

# %%
#rop duplicate rows
df.drop_duplicates(inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

missing_percent = df.isnull().mean().sort_values(ascending=False) * 100
missing_percent[missing_percent > 0].plot(kind='barh', figsize=(10, 8), title='Missing Value Percentage')
plt.xlabel('% Missing')
plt.tight_layout()
plt.show()

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# zone1_temperature               0.056227
# zone2_temperature               0.054679
# equipment_energy_consumption    0.054143
# zone1_humidity                  0.052773
# zone9_humidity                  0.052773
# zone3_humidity                  0.052237
# zone2_humidity                  0.051403
# lighting_energy                 0.051284
# zone8_temperature               0.050211
# zone6_temperature               0.050152
# zone6_humidity                  0.050092
# atmospheric_pressure            0.050092
# zone5_temperature               0.049556
# random_variable1                0.049080
# dew_point                       0.049020
# random_variable2                0.049020
# wind_speed                      0.048961
# zone4_temperature               0.048305
# visibility_index                0.048186
# outdoor_temperature             0.047769
# zone7_humidity                  0.047650
# zone3_temperature               0.047531
# zone5_humidity                  0.047472
# outdoor_humidity                0.047293
# zone7_temperature               0.046876
# zone8_humidity                  0.046221
# zone4_humidity                  0.046161
# zone9_temperature               0.045923
# timestamp                       0.000000
# dtype: float64

# %%
demo = df[['timestamp', 'zone1_temperature']].set_index('timestamp').copy()

# Create three series:
orig = demo['zone1_temperature']
ffill = orig.ffill()
linear = orig.interpolate(method='linear')
time = orig.interpolate(method='time')

plt.figure(figsize=(12, 6))
plt.plot(orig.index, orig, 'o', label='Original (with gaps)', markersize=3)
plt.plot(ffill.index, ffill, '-', label='Forward Fill')
plt.plot(linear.index, linear, '--', label='Linear Interpolation')
plt.plot(time.index, time, ':', label='Time-based Interpolation')
plt.legend()
plt.title('Imputation Comparison for zone1_temperature')
plt.xlabel('Timestamp')
plt.ylabel('Temperature (°C)')
plt.tight_layout()

plt.savefig('my_plot.png')
plt.show()

# %%
df = df.set_index('timestamp')

# %%
df.interpolate(method='time', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16789 entries, 2016-01-11 17:00:00 to 2016-12-01 15:50:00
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16789 non-null  float64
#  1   lighting_energy               16789 non-null  float64
#  2   zone1_temperature             16789 non-null  float64
#  3   zone1_humidity                16789 non-null  float64
#  4   zone2_temperature             16789 non-null  float64
#  5   zone2_humidity                16789 non-null  float64
#  6   zone3_temperature             16789 non-null  float64
#  7   zone3_humidity                16788 non-null  float64
#  8   zone4_temperature             16789 non-null  float64
#  9   zone4_humidity                16789 non-null  float64
#  10  zone5_temperature             16789 non-null  float64
#  11  zone5_humidity                16789 non-null  float64
#  12  zone6_temperature             16788 non-null  float64
#  13  zone6_humidity                16789 non-null  float64
#  14  zone7_temperature             16789 non-null  float64
#  15  zone7_humidity                16789 non-null  float64
#  16  zone8_temperature             16789 non-null  float64
#  17  zone8_humidity                16789 non-null  float64
#  18  zone9_temperature             16789 non-null  float64
#  19  zone9_humidity                16789 non-null  float64
#  20  outdoor_temperature           16789 non-null  float64
#  21  atmospheric_pressure          16789 non-null  float64
#  22  outdoor_humidity              16789 non-null  float64
#  23  wind_speed                    16789 non-null  float64
#  24  visibility_index              16789 non-null  float64
#  25  dew_point                     16789 non-null  float64
#  26  random_variable1              16789 non-null  float64
#  27  random_variable2              16789 non-null  float64
# dtypes: float64(28)
# memory usage: 3.7 MB

# %%
sns.histplot(df['equipment_energy_consumption'], kde=True, bins=30)
plt.title('Distribution of Equipment Energy Consumption')
plt.savefig('my_plot.png')
plt.show()

# %% [markdown]
# # Key Observations:
# Negative Values Present:
#
# 1) The distribution shows readings below 0 (down to -500)
# 2) Energy consumption should theoretically never be negative
# 3) Likely indicates sensor errors or data recording issues
#
# Bimodal Distribution:
# 1) Peaks around 0 and another around 500-1000
#
# Extreme Positive Outliers:
# 1) Values extend up to 12,000 with very low frequency

# %%
df.loc[df['equipment_energy_consumption'] < 0, 'equipment_energy_consumption'] = np.nan

# Then sort by timestamp and interpolate
df = df.sort_values('timestamp')
df['equipment_energy_consumption'] = df['equipment_energy_consumption'].interpolate(method='time')

# %%
Q1 = df['equipment_energy_consumption'].quantile(0.25)
Q3 = df['equipment_energy_consumption'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5*IQR  # 3σ-equivalent for non-normal data

# Create clean series while preserving outlier info
df['equipment_energy_consumption'] = np.where(df['equipment_energy_consumption'] > upper_bound,
                            upper_bound,
                            df['equipment_energy_consumption'])

# %%
sns.histplot(df['equipment_energy_consumption'], kde=True, bins=30)
plt.title('Distribution of Equipment Energy Consumption')
plt.savefig('my_plot.png')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.boxplot(x=df['equipment_energy_consumption'], flierprops=dict(marker='o', markersize=8))
plt.title("Energy Consumption Distribution with Outliers Marked")
plt.xlabel("Energy Consumption (kWh)")
plt.savefig('my_plot1.png')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16789 entries, 2016-01-11 17:00:00 to 2016-12-01 15:50:00
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16789 non-null  float64
#  1   lighting_energy               16789 non-null  float64
#  2   zone1_temperature             16789 non-null  float64
#  3   zone1_humidity                16789 non-null  float64
#  4   zone2_temperature             16789 non-null  float64
#  5   zone2_humidity                16789 non-null  float64
#  6   zone3_temperature             16789 non-null  float64
#  7   zone3_humidity                16788 non-null  float64
#  8   zone4_temperature             16789 non-null  float64
#  9   zone4_humidity                16789 non-null  float64
#  10  zone5_temperature             16789 non-null  float64
#  11  zone5_humidity                16789 non-null  float64
#  12  zone6_temperature             16788 non-null  float64
#  13  zone6_humidity                16789 non-null  float64
#  14  zone7_temperature             16789 non-null  float64
#  15  zone7_humidity                16789 non-null  float64
#  16  zone8_temperature             16789 non-null  float64
#  17  zone8_humidity                16789 non-null  float64
#  18  zone9_temperature             16789 non-null  float64
#  19  zone9_humidity                16789 non-null  float64
#  20  outdoor_temperature           16789 non-null  float64
#  21  atmospheric_pressure          16789 non-null  float64
#  22  outdoor_humidity              16789 non-null  float64
#  23  wind_speed                    16789 non-null  float64
#  24  visibility_index              16789 non-null  float64
#  25  dew_point                     16789 non-null  float64
#  26  random_variable1              16789 non-null  float64
#  27  random_variable2              16789 non-null  float64
# dtypes: float64(28)
# memory usage: 3.7 MB

# %%
df_reset = df.reset_index()

# %%
# Reset index (moves timestamps to a column)
df_plot = df.reset_index()

numeric_cols = df.select_dtypes(include=['float64']).columns
# Now create boxplots
for col in numeric_cols:
    Q1 = df_plot[col].quantile(0.25)
    Q3 = df_plot[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_plot = df_plot[(df_plot[col] >= lower_bound) & (df_plot[col] <= upper_bound)]
plt.figure(figsize=(12, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols)//3 + 1, 3, i)
    sns.boxplot(data=df_plot, y=col)  # Use data= parameter
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16789 entries, 2016-01-11 17:00:00 to 2016-12-01 15:50:00
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16789 non-null  float64
#  1   lighting_energy               16789 non-null  float64
#  2   zone1_temperature             16789 non-null  float64
#  3   zone1_humidity                16789 non-null  float64
#  4   zone2_temperature             16789 non-null  float64
#  5   zone2_humidity                16789 non-null  float64
#  6   zone3_temperature             16789 non-null  float64
#  7   zone3_humidity                16788 non-null  float64
#  8   zone4_temperature             16789 non-null  float64
#  9   zone4_humidity                16789 non-null  float64
#  10  zone5_temperature             16789 non-null  float64
#  11  zone5_humidity                16789 non-null  float64
#  12  zone6_temperature             16788 non-null  float64
#  13  zone6_humidity                16789 non-null  float64
#  14  zone7_temperature             16789 non-null  float64
#  15  zone7_humidity                16789 non-null  float64
#  16  zone8_temperature             16789 non-null  float64
#  17  zone8_humidity                16789 non-null  float64
#  18  zone9_temperature             16789 non-null  float64
#  19  zone9_humidity                16789 non-null  float64
#  20  outdoor_temperature           16789 non-null  float64
#  21  atmospheric_pressure          16789 non-null  float64
#  22  outdoor_humidity              16789 non-null  float64
#  23  wind_speed                    16789 non-null  float64
#  24  visibility_index              16789 non-null  float64
#  25  dew_point                     16789 non-null  float64
#  26  random_variable1              16789 non-null  float64
#  27  random_variable2              16789 non-null  float64
# dtypes: float64(28)
# memory usage: 3.7 MB

# %%
corr_matrix = df.corr()
plt.figure(figsize=(16,12))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.savefig('plt3.png')
plt.show()

# %%
# Check correlation of random variables
print(df[['random_variable1', 'random_variable2', 'equipment_energy_consumption']].corr())

# Output (example):
#                          random_variable1  random_variable2  equipment_energy_consumption
# random_variable1              1.000000          0.002143                     -0.000512
# random_variable2              0.002143          1.000000                      0.001038
# equipment_energy_consumption -0.000512          0.001038                      1.000000
# Out:
#                               random_variable1  random_variable2  \
# random_variable1                      1.000000          0.276509
# random_variable2                      0.276509          1.000000
# equipment_energy_consumption         -0.009702         -0.005346
#
#                               equipment_energy_consumption
# random_variable1                                 -0.009702
# random_variable2                                 -0.005346
# equipment_energy_consumption                      1.000000

# %% [markdown]
# There is no impact of random varaiable 1 and 2 on equiment_energy_consumption

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16789 entries, 2016-01-11 17:00:00 to 2016-12-01 15:50:00
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   equipment_energy_consumption  16789 non-null  float64
#  1   lighting_energy               16789 non-null  float64
#  2   zone1_temperature             16789 non-null  float64
#  3   zone1_humidity                16789 non-null  float64
#  4   zone2_temperature             16789 non-null  float64
#  5   zone2_humidity                16789 non-null  float64
#  6   zone3_temperature             16789 non-null  float64
#  7   zone3_humidity                16788 non-null  float64
#  8   zone4_temperature             16789 non-null  float64
#  9   zone4_humidity                16789 non-null  float64
#  10  zone5_temperature             16789 non-null  float64
#  11  zone5_humidity                16789 non-null  float64
#  12  zone6_temperature             16788 non-null  float64
#  13  zone6_humidity                16789 non-null  float64
#  14  zone7_temperature             16789 non-null  float64
#  15  zone7_humidity                16789 non-null  float64
#  16  zone8_temperature             16789 non-null  float64
#  17  zone8_humidity                16789 non-null  float64
#  18  zone9_temperature             16789 non-null  float64
#  19  zone9_humidity                16789 non-null  float64
#  20  outdoor_temperature           16789 non-null  float64
#  21  atmospheric_pressure          16789 non-null  float64
#  22  outdoor_humidity              16789 non-null  float64
#  23  wind_speed                    16789 non-null  float64
#  24  visibility_index              16789 non-null  float64
#  25  dew_point                     16789 non-null  float64
#  26  random_variable1              16789 non-null  float64
#  27  random_variable2              16789 non-null  float64
# dtypes: float64(28)
# memory usage: 3.7 MB

# %%
# Temperature differential features
for zone in ['zone1', 'zone2', 'zone3', 'zone4', 'zone5', 'zone6', 'zone7', 'zone8', 'zone9']:
    df[f'{zone}_temp_diff'] = df[f'{zone}_temperature'] - df['outdoor_temperature']

# Rolling window features for key variables
window_size = 4  # 4-hour rolling window
for col in ['equipment_energy_consumption', 'outdoor_temperature', 'zone1_temperature']:
    df[f'{col}_rolling_mean'] = df[col].rolling(window=window_size).mean()
    df[f'{col}_rolling_std'] = df[col].rolling(window=window_size).std()

# Drop rows with NaN values created by rolling features
df = df.dropna()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectKBest, f_regression

# Separate features and target
X = df.drop(['equipment_energy_consumption'], axis=1)
y = df['equipment_energy_consumption']

# 1. Correlation analysis
corr_matrix = df.corr()
energy_corr = corr_matrix['equipment_energy_consumption'].abs().sort_values(ascending=False)

# Select features with correlation above threshold
high_corr_features = energy_corr[energy_corr > 0.1].index.tolist()
high_corr_features.remove('equipment_energy_consumption')

# 2. Feature importance with Random Forest
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X, y)
importances = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
top_rf_features = importances[importances > 0.01].index.tolist()

# 3. Statistical feature selection
selector = SelectKBest(score_func=f_regression, k=20)
selector.fit(X, y)
selected_features = X.columns[selector.get_support()].tolist()

# Combine all selected features
all_selected_features = list(set(high_corr_features + top_rf_features + selected_features))

# Remove the random variables if they appear (based on EDA)
final_features = [f for f in all_selected_features if f not in ['random_variable1', 'random_variable2']]

# Final feature set
X_final = X[final_features]
print("Preview of the final feature set (X_final):")
print(X_final.head())
# Out:
# Preview of the final feature set (X_final):
#                      zone6_temperature  zone4_temp_diff  zone9_temp_diff  \
# timestamp
# 2016-01-11 17:30:00           6.433333        21.155572        10.750000
# 2016-01-11 17:40:00           6.366667        12.756667        -1.656822
# 2016-01-11 17:50:00           6.300000        12.873333        10.983333
# 2016-01-11 18:00:00           6.263333        30.021144        11.100000
# 2016-01-11 18:10:00           6.190000        12.973333        11.083333
#
#                      outdoor_temperature_rolling_mean  zone4_temperature  \
# timestamp
# 2016-01-11 17:30:00                          6.425000          27.405572
# 2016-01-11 17:40:00                          6.308333          18.890000
# 2016-01-11 17:50:00                          6.191667          18.890000
# 2016-01-11 18:00:00                          6.075000          35.921144
# 2016-01-11 18:10:00                          5.991667          18.890000
#
#                      zone1_temperature_rolling_mean  zone2_temperature  \
# timestamp
# 2016-01-11 17:30:00                       26.818305               19.2
# 2016-01-11 17:40:00                       23.354152               19.2
# 2016-01-11 17:50:00                       23.354152               19.2
# 2016-01-11 18:00:00                       23.354152               19.2
# 2016-01-11 18:10:00                       19.881667               19.2
#
#                      zone8_temp_diff  zone1_temp_diff  \
# timestamp
# 2016-01-11 17:30:00        11.850000        27.496609
# 2016-01-11 17:40:00        11.966667        13.756667
# 2016-01-11 17:50:00        12.083333        13.873333
# 2016-01-11 18:00:00        32.726835        13.990000
# 2016-01-11 18:10:00        12.183333        13.940000
#
#                      equipment_energy_consumption_rolling_std  \
# timestamp
# 2016-01-11 17:30:00                                  5.773503
# 2016-01-11 17:40:00                                  5.773503
# 2016-01-11 17:50:00                                  5.000000
# 2016-01-11 18:00:00                                  5.773503
# 2016-01-11 18:10:00                                  5.000000
#
#                      equipment_energy_consumption_rolling_mean  \
# timestamp
# 2016-01-11 17:30:00                                       55.0
# 2016-01-11 17:40:00                                       55.0
# 2016-01-11 17:50:00                                       52.5
# 2016-01-11 18:00:00                                       55.0
# 2016-01-11 18:10:00                                       57.5
#
#                      outdoor_humidity  zone8_temperature  zone7_temp_diff  \
# timestamp
# 2016-01-11 17:30:00         92.000000          18.100000        10.883333
# 2016-01-11 17:40:00         92.000000          18.100000        11.066667
# 2016-01-11 17:50:00         92.000000          18.100000        11.116667
# 2016-01-11 18:00:00         92.000000          38.626835        11.233333
# 2016-01-11 18:10:00         91.833333          18.100000        11.183333
#
#                      zone3_temperature  outdoor_temperature  \
# timestamp
# 2016-01-11 17:30:00              19.79             6.250000
# 2016-01-11 17:40:00              19.79             6.133333
# 2016-01-11 17:50:00              19.79             6.016667
# 2016-01-11 18:00:00              19.79             5.900000
# 2016-01-11 18:10:00              19.73             5.916667
#
#                      zone1_temperature  zone5_temp_diff  zone6_humidity  \
# timestamp
# 2016-01-11 17:30:00          33.746609        10.916667       83.423333
# 2016-01-11 17:40:00          19.890000        11.066667       84.893333
# 2016-01-11 17:50:00          19.890000        11.133333       85.766667
# 2016-01-11 18:00:00          19.890000        11.200000       86.090000
# 2016-01-11 18:10:00          19.856667        11.183333       86.423333
#
#                      lighting_energy
# timestamp
# 2016-01-11 17:30:00             40.0
# 2016-01-11 17:40:00             40.0
# 2016-01-11 17:50:00             40.0
# 2016-01-11 18:00:00             50.0
# 2016-01-11 18:10:00             50.0

# %%
from sklearn.model_selection import train_test_split

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42, shuffle=False
)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=0.1),
    'Lasso Regression': Lasso(alpha=0.1),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'XGBoost': XGBRegressor(n_estimators=100, random_state=42),

}

results = []
for name, model in models.items():
    # Train model
    model.fit(X_train, y_train)
    
    # Predict
    y_pred = model.predict(X_test)
    
    # Evaluate
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    results.append({
        'Model': name,
        'RMSE': rmse,
        'MAE': mae,
        'R2': r2
    })
    
    print(f"{name} - RMSE: {rmse:.2f}, MAE: {mae:.2f}, R2: {r2:.2f}")

# Convert results to DataFrame
results_df = pd.DataFrame(results).sort_values(by='RMSE')
# Out:
# Linear Regression - RMSE: 19.87, MAE: 12.56, R2: 0.76
# Ridge Regression - RMSE: 19.87, MAE: 12.56, R2: 0.76
# Lasso Regression - RMSE: 19.87, MAE: 12.55, R2: 0.76
# Random Forest - RMSE: 20.05, MAE: 12.47, R2: 0.76
# Gradient Boosting - RMSE: 19.60, MAE: 12.30, R2: 0.77
# XGBoost - RMSE: 21.28, MAE: 12.83, R2: 0.73

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Initialize model
gbr = GradientBoostingRegressor(random_state=42)

# Parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

# Grid search
grid_search = GridSearchCV(
    estimator=gbr,
    param_grid=param_grid,
    scoring=rmse_scorer,
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)

# Best model
best_model = grid_search.best_estimator_
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best RMSE: {-grid_search.best_score_:.2f}")

# Evaluate
y_pred = best_model.predict(X_test)
final_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
final_mae = mean_absolute_error(y_test, y_pred)
final_r2 = r2_score(y_test, y_pred)

print(f"\nGradient Boosting Performance:")
print(f"RMSE: {final_rmse:.2f}")
print(f"MAE: {final_mae:.2f}")
print(f"R2: {final_r2:.2f}")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Best RMSE: 22.62
#
# Gradient Boosting Performance:
# RMSE: 19.48
# MAE: 12.30
# R2: 0.77

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import MaxNLocator

# Assuming you have the results_df from earlier
# If not, let's recreate it from the models dictionary:

# Convert results to DataFrame
results_df = pd.DataFrame(results).sort_values(by='RMSE')

# Set style
sns.set_style("whitegrid")
plt.figure(figsize=(14, 8))

# 1. Model Comparison Bar Plot
plt.subplot(2, 2, 1)
bars = plt.barh(results_df['Model'], results_df['R2'], color=sns.color_palette("viridis", len(results_df)))
plt.title('Model Comparison (R² Score)')
plt.xlabel('R² Score')
plt.xlim(0, 1)
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:.3f}', 
             ha='left', va='center')

# 2. RMSE Comparison
plt.subplot(2, 2, 2)
bars = plt.barh(results_df['Model'], results_df['RMSE'], color=sns.color_palette("magma", len(results_df)))
plt.title('Model Comparison (RMSE)')
plt.xlabel('Root Mean Squared Error')
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width:.2f}', 
             ha='left', va='center')

# 3. Actual vs Predicted for Best Model
best_model_name = results_df.iloc[0]['Model']
best_model = models[best_model_name]
y_pred = best_model.predict(X_test)

plt.subplot(2, 2, 3)
plt.scatter(y_test, y_pred, alpha=0.5, color='royalblue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Energy Consumption')
plt.ylabel('Predicted Energy Consumption')
plt.title(f'Actual vs Predicted ({best_model_name})')

# Add R² and RMSE to the plot
plt.text(0.05, 0.9, f'R² = {results_df.iloc[0]["R2"]:.3f}\nRMSE = {results_df.iloc[0]["RMSE"]:.2f}',
         transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.8))

# 4. Residual Plot for Best Model
plt.subplot(2, 2, 4)
residuals = y_test - y_pred
plt.scatter(y_pred, residuals, alpha=0.5, color='green')
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title(f'Residual Plot ({best_model_name})')

plt.tight_layout()
plt.savefig('best_model_name.png')
plt.show()
